# %%
import requests
import random
from bs4 import BeautifulSoup

def google_search(query):
    try:
        search_url = f"https://www.google.co.uk/search?q={query}&num=1"
        response = requests.get(search_url)
        soup = BeautifulSoup(response.text, "html.parser")
        links = []
        for h3 in soup.find_all('h3'):
            a_tag = h3.find_parent('a')
            
            if a_tag and 'href' in a_tag.attrs:
                link = a_tag['href']
                link = link.split('/url?q=')[1]
                links.append(link)
        return links[0]
    except Exception as e:
        print(e)
        return ''

# %%
import pandas as pd

df = pd.read_excel('Updated_list.xlsx')

df
# Out:
#                         Name          Company  \
# 0           Audrey McLoghlin             HSBC
# 1            Robyn Streisand             HSBC
# 2                 Helen Shan             HSBC
# 3       Assad Muhammad Assad             HSBC
# 4                    Nayyira             HSBC
# ...                      ...              ...
# 2029                  Andrew  Nuffield Health
# 2030                   Joan.  Nuffield Health
# 2031         Andrew Swinburn  Nuffield Health
# 2032  Estelle Zauner Maughan  Nuffield Health
# 2033            Natalie Carr  Nuffield Health
#
#                                        Linkedin Profile
# 0     https://www.linkedin.com/in/audrey-mcloghlin-6...
# 1     https://www.linkedin.com/in/robynstreisand&sa=...
# 2     https://www.linkedin.com/in/helenshan&sa=U&ved...
# 3     https://uk.linkedin.com/in/asad-butt-130294159...
# 4     https://uk.linkedin.com/company/hsbc&sa=U&ved=...
# ...                                                 ...
# ...

# %%
df = df.astype(str)

# %%
import time
for index,row in df.iterrows():
    if row['Linkedin Profile'] == 'nan':
        name = row['Name']
        company = row['Company'] if row['Company']!='Genral' else ''
        search_text = f'{name} linkedin profile UK {company}'

        link = google_search(search_text)

        df.at[index,'Linkedin Profile'] = link
        print(f'Done for {name} and link is {link}')
# Out:
# Done for Sat Morning and link is https://uk.linkedin.com/in/simondparsons&sa=U&ved=2ahUKEwiAsLq-1_iHAxWkF1kFHSz6LA8QFnoECAAQAg&usg=AOvVaw2LE1ZDwNCp2nO4yrWwbWb9
# Done for Bill Gates and link is https://www.linkedin.com/in/williamhgates&sa=U&ved=2ahUKEwiStJPA1_iHAxVFEGIAHVIIFYgQFnoECAEQAg&usg=AOvVaw3C06Z1umUpgOFB9fNqAaU2
# Done for Gates and link is https://uk.linkedin.com/in/michael-gates-396575201&sa=U&ved=2ahUKEwjitJHB1_iHAxW-EFkFHTSLE3EQFnoECAAQAg&usg=AOvVaw17CdCcTfWTvcWhvcvw1hAm
# Done for Athalie Williams and link is https://uk.linkedin.com/in/athalie-williams-hr&sa=U&ved=2ahUKEwiB6qrD1_iHAxWcMlkFHc-zMcwQFnoECAAQAg&usg=AOvVaw0BDVDM7Pl2503M0erjBmPM
# Done for Philip Jansen and link is https://www.linkedin.com/posts/bt_philip-jansen-bt-group-full-year-results-activity-7064906077573652480-4IlB&sa=U&ved=2ahUKEwill5vE1_iHAxU_E1kFHVfCCr4QFnoECAAQAg&usg=AOvVaw2fRNObPnmRVYHLt2OnUzdA
# ...

# %%
df.to_excel('Updated_list.xlsx',index=False)

# %%
import openpyxl
from openpyxl.utils import get_column_letter

def convert_urls_to_hyperlinks(excel_file, sheet_name, url_column):
    workbook = openpyxl.load_workbook(excel_file)
    sheet = workbook[sheet_name]

    col_letter = get_column_letter(url_column)

    for row in range(2, sheet.max_row + 1): 
        cell = sheet[f"{col_letter}{row}"]
        if isinstance(cell.value, str) and cell.value.startswith("http"):
            sheet[f"{col_letter}{row}"].hyperlink = cell.value
            sheet[f"{col_letter}{row}"].value = cell.value
            sheet[f"{col_letter}{row}"].style = "Hyperlink"

    workbook.save(excel_file)

excel_file = 'Updated_list.xlsx'
sheet_name = "Sheet1"
url_column = 3  

convert_urls_to_hyperlinks(excel_file, sheet_name, url_column)
